# %%
import numpy as np
import pandas as pd

# %%
sim_path = '/home/ryuga/Documentos/Mestrado/Benchmark/DataBaseTennessee/database/data/'
sim_df = pd.read_csv(sim_path + 'simout_1.csv', index_col='tout')

# %%
sim_df.head()
# Out:
#         xmeas1       xmeas2       xmeas3    xmeas4     xmeas5     xmeas6  \
# tout
# 0.00  0.271033  3649.739415  4451.320791  9.223142  32.392900  47.559754
# 0.01  0.271854  3689.335983  4444.457491  9.252574  32.181103  47.771091
# 0.02  0.271240  3645.222439  4444.585389  9.210965  32.626982  47.648657
# 0.03  0.270623  3653.224156  4459.600050  9.314207  32.492805  47.578617
# 0.04  0.271336  3668.223751  4486.720169  9.247881  32.295343  47.595052
#
#            xmeas7     xmeas8      xmeas9   xmeas10    ...       xmeas32  \
# tout                                                  ...
# 0.00  2798.975799  64.995825  122.898796  0.197826    ...      0.895836
# 0.01  2799.108851  64.357595  122.892692  0.196082    ...      0.895836
# 0.02  2798.964034  63.644355  122.918317  0.197222    ...      0.895836
# 0.03  2798.605420  64.829800  122.916964  0.195026    ...      0.895836
# 0.04  2799.243255  64.585296  122.902800  0.200729    ...      0.895836
#
# ...

# %%
sim_df.tail()
# Out:
#          xmeas1       xmeas2       xmeas3    xmeas4     xmeas5     xmeas6  \
# tout
# 57.96  0.267410  3646.394623  4498.076001  9.279976  32.221200  47.443655
# 57.97  0.266642  3640.637789  4445.762433  9.223289  32.357909  47.445280
# 57.98  0.267040  3640.322830  4493.464567  9.240163  32.640085  47.510746
# 57.99  0.266973  3640.762591  4481.464877  9.183311  32.270994  47.673104
# 58.00  0.266266  3601.093840  4480.761123  9.193488  32.633342  47.564800
#
#             xmeas7     xmeas8      xmeas9   xmeas10    ...       xmeas32  \
# tout                                                   ...
# 57.96  2799.504344  64.483465  122.913425  0.212902    ...      0.830048
# 57.97  2798.845251  64.412752  122.908317  0.212853    ...      0.830048
# 57.98  2799.151764  65.143990  122.892860  0.215343    ...      0.830048
# 57.99  2799.005304  65.258298  122.904732  0.207394    ...      0.830048
# 58.00  2799.223097  65.015079  122.911423  0.209422    ...      0.830048
#
# ...

# %%
sim_df.describe()
# Out:
#             xmeas1       xmeas2       xmeas3       xmeas4       xmeas5  \
# count  5801.000000  5801.000000  5801.000000  5801.000000  5801.000000
# mean      0.266830  3655.127090  4441.364539     9.235431    32.418641
# std       0.006033    18.958260    23.931580     0.051728     0.203415
# min       0.247501  3579.498020  4334.705321     9.058125    31.667110
# 25%       0.262743  3642.540315  4425.535157     9.201960    32.278920
# 50%       0.266934  3655.387190  4440.918052     9.234260    32.418100
# 75%       0.270903  3668.061742  4457.622995     9.270585    32.557095
# max       0.286059  3721.478051  4520.501296     9.414611    33.148483
#
#             xmeas6       xmeas7       xmeas8       xmeas9      xmeas10  \
# count  5801.000000  5801.000000  5801.000000  5801.000000  5801.000000
# mean     47.597387  2800.006768    64.988188   122.899848     0.212033
# std       0.211018     1.008714     0.503916     0.010814     0.010045
# ...

# %%
pd.to_datetime(sim_df.index, unit='h')
# Out:
# DatetimeIndex(['1970-01-01 00:00:00', '1970-01-01 00:00:36',
#                '1970-01-01 00:01:12', '1970-01-01 00:01:48',
#                '1970-01-01 00:02:24', '1970-01-01 00:03:00',
#                '1970-01-01 00:03:36', '1970-01-01 00:04:12',
#                '1970-01-01 00:04:48', '1970-01-01 00:05:24',
#                ...
#                '1970-01-03 09:54:36', '1970-01-03 09:55:12',
#                '1970-01-03 09:55:48', '1970-01-03 09:56:24',
#                '1970-01-03 09:57:00', '1970-01-03 09:57:36',
#                '1970-01-03 09:58:12', '1970-01-03 09:58:48',
#                '1970-01-03 09:59:24', '1970-01-03 10:00:00'],
#               dtype='datetime64[ns]', name='tout', length=5801, freq=None)

# %%
sim_df.index = pd.to_datetime(sim_df.index, unit='h')
sim_df
